# %% [markdown]
# # Assignment 4 — Setup
# This notebook checks the environment and imports your from-scratch implementations.

# %%
import sys, numpy as np
print(sys.version)
print('numpy', np.__version__)
# Out:
# 3.13.2 (tags/v3.13.2:4f8bb39, Feb  4 2025, 15:23:48) [MSC v.1942 64 bit (AMD64)]
# numpy 2.2.3

# %%
import os
os.chdir('..')
print('cwd:', os.getcwd())
# Out:
# cwd: d:\Term 7\Machine Learning\ML-projects\ml_assignment4

# %%
import sys
sys.path.append('.')
from src.dimred.pca import PCA
from src.clustering.kmeans import KMeans
from src.clustering.gmm import GMM
from src.dimred.autoencoder import Autoencoder
print('Imports OK')
# Out:
# Imports OK
